# %%
import pandas as pd
import numpy as np
n=100
cities=np.empty((n,3))
cities[:,0]=np.array(range(n))+1
cities[:,1:]=np.random.rand(n,2)*10
cities={'id':cities[:,0],'x':cities[:,1],'y':cities[:,2]}
cities=pd.DataFrame(cities)
cities.head(10)
# Out:
#      id         x         y
# 0   1.0  2.998044  7.490247
# 1   2.0  4.813636  1.668871
# 2   3.0  3.251841  0.482010
# 3   4.0  1.611322  4.242716
# 4   5.0  3.460594  7.073389
# 5   6.0  7.211225  2.236978
# 6   7.0  5.843165  1.352851
# 7   8.0  5.706554  0.035289
# 8   9.0  9.146575  2.940518
# 9  10.0  2.918311  4.565461

# %%
cities.to_csv(path_or_buf="./data/cities.csv", sep=" ",index=False,mode='w+')
