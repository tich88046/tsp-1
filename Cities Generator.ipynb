# %%
import pandas as pd
import numpy as np
n=100
cities=np.empty((n,3))
cities[:,0]=np.array(range(n))+1
cities[:,1:]=np.random.rand(n,2)*10
cities={'id':cities[:,0],'x':cities[:,1],'y':cities[:,2]}
cities=pd.DataFrame(cities)
print(cities)
cities.to_csv(path_or_buf="./data/cities.csv", sep=" ",index=False,mode='w+')
# Out:
#        id         x         y
# 0     1.0  4.402697  2.765788
# 1     2.0  5.958713  2.620193
# 2     3.0  5.834281  1.146536
# 3     4.0  6.162438  2.732059
# 4     5.0  8.647736  2.385628
# 5     6.0  5.785095  4.952035
# 6     7.0  7.665969  5.436100
# 7     8.0  0.057217  8.013576
# 8     9.0  1.104507  0.997933
# 9    10.0  2.425010  7.873991
# 10   11.0  6.713644  8.276397
# 11   12.0  3.663818  4.524720
# 12   13.0  0.135066  8.137879
# 13   14.0  6.744607  7.292986
# 14   15.0  3.305582  0.262337
# 15   16.0  7.823141  1.887282
# 16   17.0  3.192537  6.592139
# 17   18.0  9.337663  5.210305
# 18   19.0  6.743710  5.401262
# 19   20.0  4.930979  7.414896
# 20   21.0  1.821713  3.055080
# 21   22.0  2.447480  1.376390
# 22   23.0  6.765084  2.817573
# 23   24.0  8.788485  3.085145
# 24   25.0  0.461457  1.957414
# 25   26.0  6.588987  9.250988
# 26   27.0  4.544191  7.979363
# 27   28.0  5.780657  9.956779
# 28   29.0  7.970336  3.757196
# 29   30.0  2.716424  6.223129
# ..    ...       ...       ...
# 70   71.0  9.324325  3.958823
# 71   72.0  5.226890  4.377058
# 72   73.0  5.240799  0.961289
# 73   74.0  9.062209  9.045446
# 74   75.0  6.079813  5.993540
# 75   76.0  5.231127  5.455458
# 76   77.0  7.961985  3.882515
# 77   78.0  1.179132  8.464245
# 78   79.0  0.638940  8.903206
# 79   80.0  3.145704  5.657191
# 80   81.0  5.995144  7.931306
# 81   82.0  6.455027  2.065754
# 82   83.0  3.277125  1.328655
# 83   84.0  8.085010  4.761031
# 84   85.0  0.269187  9.449470
# 85   86.0  2.637785  0.823610
# 86   87.0  7.338843  5.116980
# 87   88.0  7.431347  3.290883
# 88   89.0  4.186672  4.019474
# 89   90.0  6.131714  1.566000
# 90   91.0  0.236493  4.021461
# 91   92.0  2.481557  7.239963
# 92   93.0  6.157337  7.311634
# 93   94.0  4.227390  1.099610
# 94   95.0  0.240081  5.162252
# 95   96.0  0.335199  7.274911
# 96   97.0  7.159449  9.347469
# 97   98.0  4.042073  4.911752
# 98   99.0  7.001941  6.694111
# 99  100.0  9.742638  8.543020
#
# [100 rows x 3 columns]
